# %% [markdown]
# #Descubra o seu número de Caminho da Vida

# %%
#Solicitando ao usuário que se identifique
nome = input('Olá! Qual o seu nome? ')

#Saldação ao usuário
print(f'Seja bem-vindo(a), {nome}.')

#Solicitando as informações de data de nascimento para chegarmos ao número de destino
dia = input('Vamos começar com o dia do seu aniversário: ')
mes = input('Perfeito! Agora me informe qual o mês do seu nascimento: ')
ano = input('Estamos quase lá! Me informe o ano do seu nascimento: ')

#Separando os valores em dígitos e criando uma lista final
digitos_dia = list(dia)
digitos_mes = list(mes)
digitos_ano = list(ano)
digitos_final = digitos_dia + digitos_mes +digitos_ano

#Transformando os valores em inteiros para conseguirmos somar
digitos_int = [int(x) for x in digitos_final]

#Somando os valores inteiros
soma1 = 0

for numero in digitos_int:
  soma1 += numero

#Transformando o resultado da soma em string, para podermos separar os dígitos e realizar a soma final
soma1_final = str(soma1)
digitos_soma1 = list(soma1_final)

#Transformando novamente os valores em inteiros para somarmos o valor final
soma1_int = [int(x) for x in digitos_soma1]

#Somando os valores inteiros fianis
soma2 = 0

for numero in soma1_int:
  soma2 += numero

print(f'O seu número do caminho da vida é {soma2} . É a base principal da sua personalidade!')
print('Vamos ver o que isso significa...')

#Significados de 1 a 9

if soma2 == 1:
  print('O número que inicia, que chega, que faz. Você deve possuir uma capacidade nata de liderança, possui natureza corajosa e é aquele que abre o caminho!')

elif soma2 == 2:
  print('Você possui uma questão forte com a diplomacia e a empatia. Sempre se coloca a favor das relações humanas. Gosta de entender os dois lados de uma história!')

elif soma2 == 3:
  print('Você costuma unir o útil ao agradável e à ação! Consegue expor de um jeito muito simples suas ideias e tudo que vem a cabeça. Gosta de fazer acontecer!')

elif soma2 == 4:
  print('Este é o número de base, que traz questões voltadas para estabilidade e a metodologia. Você tende a ser mais racional, gosta de rotina. Preza pelo conforto e estabilidade.')

elif soma2 == 5:
  print('Você gosta de coisas novas, de liberdade, de autonomia pessoal. Este é o númedo de mudanças, de transição.')

elif soma2 == 6:
   print('Você é reconhecido(a) pela afetividade e amor. É compreensivo(a), busca sempre uma harmonia com o mundo. Este número também é voltado ao trabalho e pode trazer engajamento profissional.')

elif soma2 == 7:
  print('Você é observador(a) e cauteloso(a). Gosta de análise e possui senso crítico forte. O número 7 é voltado à intelectualidade, com forte vocação aos estudos e pesquisas.')

elif soma2 == 8:
  print('Você é determinada, focada e com uma relação muito forte com o sucesso financeiro e profissional. Não costuma falar das suas fraquezas. Traz grande excelência em tudo que faz e pode ser inflexível.')

elif soma2 == 9:
  print('Você tem a capacidade de conseguir se envolver com muitas pessoas ao mesmo tempo e está sempre proximo dos amigos. É uma pessoa flexível e muito sociável, com empatia forte.')

#Transformando os valores em inteiros para as outras operações
dia_int = int(dia)
mes_int = int(mes)
ano_int = int(ano)

#Trabalhando a diferença entre partes da data (Dia - Mês)
subtracao = dia_int - mes_int

print(f'O resultado da diferença entre dia e mês é {subtracao} !')

#Significados de 1 a 9

if subtracao == 1:
  print('O número que inicia, que chega, que faz. Você deve possuir uma capacidade nata de liderança, possui natureza corajosa e é aquele que abre o caminho!')

elif subtracao == 2:
  print('Você possui uma questão forte com a diplomacia e a empatia. Sempre se coloca a favor das relações humanas. Gosta de entender os dois lados de uma história!')

elif subtracao == 3:
  print('Você costuma unir o útil ao agradável e à ação! Consegue expor de um jeito muito simples suas ideias e tudo que vem a cabeça. Gosta de fazer acontecer!')

elif subtracao == 4:
  print('Este é o número de base, que traz questões voltadas para estabilidade e a metodologia. Você tende a ser mais racional, gosta de rotina. Preza pelo conforto e estabilidade.')

elif subtracao == 5:
  print('Você gosta de coisas novas, de liberdade, de autonomia pessoal. Este é o númedo de mudanças, de transição.')

elif subtracao == 6:
   print('Você é reconhecido(a) pela afetividade e amor. É compreensivo(a), busca sempre uma harmonia com o mundo. Este número também é voltado ao trabalho e pode trazer engajamento profissional.')

elif subtracao == 7:
  print('Você é observador(a) e cauteloso(a). Gosta de análise e possui senso crítico forte. O número 7 é voltado à intelectualidade, com forte vocação aos estudos e pesquisas.')

elif subtracao == 8:
  print('Você é determinada, focada e com uma relação muito forte com o sucesso financeiro e profissional. Não costuma falar das suas fraquezas. Traz grande excelência em tudo que faz e pode ser inflexível.')

elif subtracao == 9:
  print('Você tem a capacidade de conseguir se envolver com muitas pessoas ao mesmo tempo e está sempre proximo dos amigos. É uma pessoa flexível e muito sociável, com empatia forte.')

#Trabalhando a multiplicação entre partes da data (Dia * Mês)
multiplicacao = dia_int * mes_int

#Transformando o resultado da multiplicação em string, para podermos separar os dígitos e realizar a soma final
mult_str = str(multiplicacao)
digitos_mult = list(mult_str)

#Transformando novamente os valores em inteiros para somarmos o valor final
mult_int = [int(x) for x in digitos_mult]

#Somando os valores inteiros fianis
soma3 = 0

for numero in mult_int:
  soma3 += numero

print(f'O resultado da multiplicação entre dia e mês é {soma3} !')

#Significados de 1 a 10

if soma3 == 1:
  print('O número que inicia, que chega, que faz. Você deve possuir uma capacidade nata de liderança, possui natureza corajosa e é aquele que abre o caminho!')

elif soma3 == 2:
  print('Você possui uma questão forte com a diplomacia e a empatia. Sempre se coloca a favor das relações humanas. Gosta de entender os dois lados de uma história!')

elif soma3 == 3:
  print('Você costuma unir o útil ao agradável e à ação! Consegue expor de um jeito muito simples suas ideias e tudo que vem a cabeça. Gosta de fazer acontecer!')

elif soma3 == 4:
  print('Este é o número de base, que traz questões voltadas para estabilidade e a metodologia. Você tende a ser mais racional, gosta de rotina. Preza pelo conforto e estabilidade.')

elif soma3 == 5:
  print('Você gosta de coisas novas, de liberdade, de autonomia pessoal. Este é o númedo de mudanças, de transição.')

elif soma3 == 6:
   print('Você é reconhecido(a) pela afetividade e amor. É compreensivo(a), busca sempre uma harmonia com o mundo. Este número também é voltado ao trabalho e pode trazer engajamento profissional.')

elif soma3 == 7:
  print('Você é observador(a) e cauteloso(a). Gosta de análise e possui senso crítico forte. O número 7 é voltado à intelectualidade, com forte vocação aos estudos e pesquisas.')

elif soma3 == 8:
  print('Você é determinada, focada e com uma relação muito forte com o sucesso financeiro e profissional. Não costuma falar das suas fraquezas. Traz grande excelência em tudo que faz e pode ser inflexível.')

elif soma3 == 9:
  print('Você tem a capacidade de conseguir se envolver com muitas pessoas ao mesmo tempo e está sempre proximo dos amigos. É uma pessoa flexível e muito sociável, com empatia forte.')

elif soma3 >= 10:
  print('O número que inicia, que chega, que faz. Você deve possuir uma capacidade nata de liderança, possui natureza corajosa e é aquele que abre o caminho!')

#Trabalhando a divisão do ano e dia
divisao = ano_int // dia_int

#Transformando o resultado da divisão em string, para podermos separar os dígitos e realizar a soma final
div_str = str(divisao)
digitos_div = list(div_str)

#Transformando novamente os valores em float para somarmos o valor final
div_int = [int(x) for x in digitos_div]

#Somando os valores inteiros fianis
soma4 = 0

for numero in div_int:
  soma4 += numero

print(f'O resultado da divisão entre ano e dia é {soma4} !')

#Significados de 1 a 10

if soma4 == 1:
  print('O número que inicia, que chega, que faz. Você deve possuir uma capacidade nata de liderança, possui natureza corajosa e é aquele que abre o caminho!')

elif soma4 == 2:
  print('Você possui uma questão forte com a diplomacia e a empatia. Sempre se coloca a favor das relações humanas. Gosta de entender os dois lados de uma história!')

elif soma4 == 3:
  print('Você costuma unir o útil ao agradável e à ação! Consegue expor de um jeito muito simples suas ideias e tudo que vem a cabeça. Gosta de fazer acontecer!')

elif soma4 == 4:
  print('Este é o número de base, que traz questões voltadas para estabilidade e a metodologia. Você tende a ser mais racional, gosta de rotina. Preza pelo conforto e estabilidade.')

elif soma4 == 5:
  print('Você gosta de coisas novas, de liberdade, de autonomia pessoal. Este é o númedo de mudanças, de transição.')

elif soma4 == 6:
   print('Você é reconhecido(a) pela afetividade e amor. É compreensivo(a), busca sempre uma harmonia com o mundo. Este número também é voltado ao trabalho e pode trazer engajamento profissional.')

elif soma4 == 7:
  print('Você é observador(a) e cauteloso(a). Gosta de análise e possui senso crítico forte. O número 7 é voltado à intelectualidade, com forte vocação aos estudos e pesquisas.')

elif soma4 == 8:
  print('Você é determinada, focada e com uma relação muito forte com o sucesso financeiro e profissional. Não costuma falar das suas fraquezas. Traz grande excelência em tudo que faz e pode ser inflexível.')

elif soma4 == 9:
  print('Você tem a capacidade de conseguir se envolver com muitas pessoas ao mesmo tempo e está sempre proximo dos amigos. É uma pessoa flexível e muito sociável, com empatia forte.')

elif soma4 >= 10:
  print('O número que inicia, que chega, que faz. Você deve possuir uma capacidade nata de liderança, possui natureza corajosa e é aquele que abre o caminho!')
# Out:
# Olá! Qual o seu nome? Marina
# Seja bem-vindo(a), Marina.
# Vamos começar com o dia do seu aniversário: 14
# Perfeito! Agora me informe qual o mês do seu nascimento: 11
# Estamos quase lá! Me informe o ano do seu nascimento: 1995
# O seu número do caminho da vida é 4 . É a base principal da sua personalidade!
# Vamos ver o que isso significa...
# Este é o número de base, que traz questões voltadas para estabilidade e a metodologia. Você tende a ser mais racional, gosta de rotina. Preza pelo conforto e estabilidade.
# O resultado da diferença entre dia e mês é 3 !
# Você costuma unir o útil ao agradável e à ação! Consegue expor de um jeito muito simples suas ideias e tudo que vem a cabeça. Gosta de fazer acontecer!
# O resultado da multiplicação entre dia e mês é 10 !
# O número que inicia, que chega, que faz. Você deve possuir uma capacidade nata de liderança, possui natureza corajosa e é aquele que abre o caminho!
# O resultado da divisão entre ano e dia é 7 !
# ...
